# %% [markdown]
# #Statistics Part 2

# %% [markdown]
# ## Q1. What is hypothesis testing in statistics?
#
# ### Answer:
# Hypothesis testing is a statistical method used to make decisions or inferences about a population based on sample data. It helps determine whether the observed data provides enough evidence to reject a specific assumption about a population parameter.
#
# In hypothesis testing, two competing statements are formed:
#
# - **Null Hypothesis (H₀):** Assumes that there is no effect, no difference, or no relationship. It represents the default or status quo.
# - **Alternative Hypothesis (H₁ or Ha):** Suggests that there is an effect, a difference, or a relationship. It represents what the researcher wants to prove.
#
# ## Q2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# ### Answer:
# In hypothesis testing, two statements are made to test assumptions about a population:
#
# - **Null Hypothesis (H₀):**
#   It states that there is **no effect**, **no difference**, or **no relationship**. It represents the current situation or a claim that is assumed to be true unless there is strong evidence against it.
#
# - **Alternative Hypothesis (H₁ or Ha):**
#   It suggests that there **is an effect**, **a difference**, or **a relationship**. Researchers try to find evidence to support this claim.
#
# ### Difference:
# The null hypothesis represents the default or no-change condition, while the alternative hypothesis proposes that something has changed or there is a significant effect. Hypothesis testing helps determine which statement is supported by the data.
#
#
# ## Q3. What is the significance level in hypothesis testing, and why is it important?
#
# ### Answer:
# The **significance level (α)** is the probability of making a **Type I error**, which means rejecting the null hypothesis when it is actually true. It defines how much risk of error the researcher is willing to accept.
#
# ### Common Values of α:
# - 0.05 (5%) — Most commonly used.
# - 0.01 (1%) — Stricter, used for more precise studies.
#
# ### Importance:
# - It helps decide whether the observed results are **statistically significant**.
# - A smaller α reduces the chances of making incorrect conclusions.
# - It provides a clear rule for decision-making in hypothesis testing.
#
# ## Q4. What does a P-value represent in hypothesis testing?
#
# ### Answer:
# The **P-value** is the probability of observing the sample results, or more extreme results, if the **null hypothesis (H₀)** is true.
#
# ### Interpretation:
# - A **small P-value** (typically ≤ 0.05) indicates strong evidence **against** the null hypothesis, so we reject H₀.
# - A **large P-value** (> 0.05) indicates weak evidence against H₀, so we fail to reject H₀.
#
# ## Q5. How do you interpret the P-value in hypothesis testing?
#
# ### Answer:
# The **P-value** helps us decide whether to reject or fail to reject the null hypothesis (H₀).
#
# ### Interpretation Rules:
# - If **P-value ≤ significance level (α)** (commonly 0.05):
#   → Reject the null hypothesis.
#   → The result is **statistically significant**.
#
# - If **P-value > significance level (α)**:
#   → Fail to reject the null hypothesis.
#   → There is **not enough evidence** to say the result is significant.
#
# ### Example:
# - If P-value = 0.03 and α = 0.05 → Reject H₀, result is significant.
# - If P-value = 0.08 and α = 0.05 → Fail to reject H₀, result is not significant.
#
# ## Q6. What are Type 1 and Type 2 errors in hypothesis testing?
#
# ### Answer:
# In hypothesis testing, two types of errors can occur when making decisions:
#
# ### Type 1 Error (False Positive):
# - Occurs when the **null hypothesis (H₀)** is rejected even though it is actually true.
# - In simple terms: Detecting an effect or difference that does **not** actually exist.
# - The probability of making a Type 1 error is equal to the **significance level (α)**.
#
# ### Type 2 Error (False Negative):
# - Occurs when the **null hypothesis (H₀)** is **not rejected**, even though it is actually false.
# - In simple terms: Failing to detect an effect or difference that **actually exists**.
# - The probability of making a Type 2 error is denoted by **β**.
#
# ## Q7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# ### Answer:
# In hypothesis testing, the choice between a **one-tailed** or **two-tailed** test depends on the direction of the research question.
#
# ### One-Tailed Test:
# - Tests for an effect in **one specific direction** (either greater than or less than).
# - The entire significance level (α) is placed on one side of the distribution.
# - Used when the researcher wants to check for improvement or reduction only.
#
# **Example:**
# - Checking if a new drug **increases** recovery rate (right-tailed test).
# - Checking if a process **reduces** defects (left-tailed test).
#
# ### Two-Tailed Test:
# - Tests for an effect in **both directions** (either greater or less).
# - The significance level (α) is split equally between both tails of the distribution.
# - Used when the researcher wants to check for any difference, regardless of direction.
#
# **Example:**
# - Checking if a new teaching method results in **any change** in test scores (increase or decrease).
#
# ## Q8. What is the Z-test, and when is it used in hypothesis testing?
#
# ### Answer:
# The **Z-test** is a statistical test used to determine whether there is a significant difference between sample and population means, or between the means of two samples, when the population standard deviation is known.
#
# ### When to Use a Z-test:
# - The sample size is **large** (usually n ≥ 30).
# - The population follows a **normal distribution** or the sample size is large enough for the Central Limit Theorem to apply.
# - The **population standard deviation (σ)** is known.
#
# ## Q9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# ### Answer:
# The **Z-score** measures how many standard deviations a data point or sample mean is away from the population mean.
#
# ### Formula to Calculate Z-score:
#
# \[
# Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
# \]
#
# Where:
# - **Z** = Z-score
# - **𝑋̄** = Sample mean
# - **μ** = Population mean
# - **σ** = Population standard deviation
# - **n** = Sample size
#
# ### What it Represents:
# - The Z-score shows the position of the sample mean relative to the population mean.
# - A **high absolute Z-score** indicates that the sample mean is far from the population mean, suggesting the result may be statistically significant.
# - The Z-score is compared to critical values to decide whether to reject the null hypothesis.
#
# ## Q10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
# ### Answer:
# The **T-distribution**, also called **Student's T-distribution**, is a probability distribution similar to the normal distribution but with heavier tails. It is used when estimating population parameters with small sample sizes and when the population standard deviation is unknown.
#
# ### When to Use the T-distribution:
# - The sample size is **small** (n < 30).
# - The population standard deviation (σ) is **unknown**.
# - The data is approximately **normally distributed**.
#
# ## Q11. What is the difference between a Z-test and a T-test?
#
# ### Answer:
# The **Z-test** and **T-test** are both used in hypothesis testing to compare means, but they differ based on sample size and whether the population standard deviation is known.
#
# ### Z-test:
# - Used when the **population standard deviation (σ)** is **known**.
# - Sample size is **large** (n ≥ 30).
# - Assumes the population follows a **normal distribution**.
#
# ### T-test:
# - Used when the **population standard deviation (σ)** is **unknown**.
# - Sample size is **small** (n < 30).
# - Based on the **T-distribution**, which has heavier tails to account for more uncertainty.
#
# ## Q12. What is the T-test, and how is it used in hypothesis testing?
#
# ### Answer:
# The **T-test** is a statistical test used to determine whether there is a significant difference between the means of two groups or between a sample mean and a known value, especially when the sample size is small and the population standard deviation is unknown.
#
# ### When to Use the T-test:
# - Sample size is **small** (n < 30).
# - **Population standard deviation (σ)** is unknown.
# - The population is approximately **normally distributed**.
#
# ### Types of T-tests:
# 1. **One-sample T-test:**
#    Tests if the sample mean differs from a known population mean.
# 2. **Independent two-sample T-test:**
#    Compares the means of two independent groups.
# 3. **Paired T-test:**
#    Compares means from the same group at different times or under different conditions.
#
# ### How it is Used:
# 1. State the null and alternative hypotheses.
# 2. Calculate the **T-statistic** using sample data.
# 3. Compare the T-statistic to critical values from the **T-distribution table**, or use the **P-value**.
# 4. Make a decision to reject or fail to reject the null hypothesis.
#
# ## Q13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# ### Answer:
# The **Z-test** and **T-test** are both statistical methods used to test hypotheses about population means. They serve a similar purpose but are used under different conditions.
#
# ### Relationship and Key Points:
# - Both tests help determine if there is a significant difference between sample data and population parameters.
# - The **T-test** is considered an extension of the **Z-test** for situations where the population standard deviation (σ) is unknown.
# - As the sample size increases, the **T-distribution** becomes similar to the **normal distribution**, making the **T-test and Z-test results nearly identical** for large samples.
#
# ## Q14. What is a confidence interval, and how is it used to interpret statistical results?
#
# ### Answer:
# A **confidence interval (CI)** is a range of values, calculated from sample data, that is likely to contain the true population parameter (such as the mean or proportion) with a certain level of confidence.
#
# ### Example:
# A 95% confidence interval means we are 95% confident that the true population parameter lies within that range.
#
# ### How it is Used:
# - Confidence intervals give an estimate of the range within which the true value lies.
# - Instead of giving just a single estimate (point estimate), a CI provides a range, making the result more informative.
# - Wider intervals indicate more uncertainty; narrower intervals indicate more precision.
#
# ### Interpretation:
# If the 95% CI for the difference between two means is (2.5, 5.0), we can say with 95% confidence that the true difference lies between 2.5 and 5.0.
# If the CI includes **0**, it suggests that there may be no significant difference.
#
# ## Q15. What is the margin of error, and how does it affect the confidence interval?
#
# ### Answer:
# The **margin of error (MoE)** is the amount added and subtracted from the sample estimate to create a confidence interval. It reflects the uncertainty or possible error in estimating the population parameter.
#
# ### Formula (for mean with known σ):
# \[
# \text{Margin of Error} = Z \times \frac{\sigma}{\sqrt{n}}
# \]
# Where:
# - **Z** = Z-score based on confidence level (e.g., 1.96 for 95%)
# - **σ** = Population standard deviation
# - **n** = Sample size
#
# ### How it Affects the Confidence Interval:
# - The **margin of error** determines the width of the confidence interval.
# - A **larger margin of error** results in a **wider** confidence interval, indicating more uncertainty.
# - A **smaller margin of error** results in a **narrower** confidence interval, indicating more precision.
#
# ## Q16. How is Bayes' Theorem used in statistics, and what is its significance?
#
# ### Answer:
# **Bayes' Theorem** is a fundamental concept in statistics that describes how to update the probability of a hypothesis based on new evidence or information.
#
# ### Formula:
# \[
# P(A|B) = \frac{P(B|A) \times P(A)}{P(B)}
# \]
# Where:
# - **P(A|B)** = Probability of event A given event B has occurred (posterior probability)
# - **P(B|A)** = Probability of event B given event A has occurred (likelihood)
# - **P(A)** = Prior probability of event A
# - **P(B)** = Total probability of event B
#
# ### How It Is Used:
# - To update probabilities as new information becomes available.
# - Common in **medical testing**, **machine learning**, **decision making**, and **spam detection**.
# - Helps in understanding the impact of new evidence on existing beliefs.
#
# ### Significance:
# - It provides a systematic way to revise predictions or beliefs based on new data.
# - It plays a key role in **Bayesian statistics**, which is widely used in modern data analysis and real-world decision-making under uncertainty.
#
# ## Q17. What is the Chi-square distribution, and when is it used?
#
# ### Answer:
# The **Chi-square (χ²) distribution** is a probability distribution that is commonly used in statistics to analyze categorical data and to test relationships between variables.
#
# ### When it is Used:
# The Chi-square distribution is mainly used for:
# 1. **Chi-square goodness-of-fit test:**
#    - To check if observed data matches an expected distribution.
# 2. **Chi-square test of independence:**
#    - To test whether two categorical variables are independent or related.
# 3. **Variance testing:**
#    - To test hypotheses about population variance.
#
# ## Q18. What is the Chi-square goodness of fit test, and how is it applied?
#
# ### Answer:
# The **Chi-square goodness of fit test** is a statistical test used to determine whether a set of observed frequencies matches the expected frequencies for a categorical variable.
#
# ### Formula:
# \[
# \chi^2 = \sum \frac{(O - E)^2}{E}
# \]
# Where:
# - **O** = Observed frequency
# - **E** = Expected frequency
#
# ### Steps to Apply the Test:
# 1. State the null hypothesis (**H₀**): The observed frequencies fit the expected distribution.
# 2. Calculate the expected frequencies.
# 3. Compute the Chi-square statistic using the formula.
# 4. Compare the calculated value to the critical value from the Chi-square distribution table based on degrees of freedom.
# 5. Make a decision:
#    - If calculated χ² > critical value → Reject H₀ (significant difference).
#    - If calculated χ² ≤ critical value → Fail to reject H₀ (no significant difference).
#
# ## Q19. What is the F-distribution, and when is it used in hypothesis testing?
#
# ### Answer:
# The **F-distribution** is a continuous probability distribution that arises when comparing two sample variances. It is commonly used in hypothesis testing to analyze whether there are significant differences between group variances or means.
#
# ### When it is Used:
# - **ANOVA (Analysis of Variance):** To compare means of three or more groups.
# - **Test for Equality of Variances:** To compare the variances of two populations.
#
# ## Q20. What is an ANOVA test, and what are its assumptions?
#
# ### Answer:
# **ANOVA (Analysis of Variance)** is a statistical test used to compare the means of three or more groups to determine if at least one group mean is significantly different from the others.
#
# ### Assumptions of ANOVA:
# 1. **Independence:** The observations in each group are independent.
# 2. **Normality:** The data within each group is approximately normally distributed.
# 3. **Homogeneity of Variances (Equal Variances):** The variances across groups are roughly equal.
#
# ## Q21. What are the different types of ANOVA tests?
#
# ### Answer:
# There are several types of **ANOVA (Analysis of Variance)** tests, each designed for specific experimental setups and research questions.
#
# ### 1. One-Way ANOVA:
# - Compares the means of **three or more independent groups** based on a **single independent variable**.
# - Example: Comparing test scores of students taught using three different teaching methods.
#
# ### 2. Two-Way ANOVA:
# - Examines the effects of **two independent variables** on a dependent variable.
# - Also tests for **interaction effects** between the two factors.
# - Example: Studying the impact of both teaching method and gender on student performance.
#
# ### 3. Repeated Measures ANOVA:
# - Used when the **same subjects** are measured multiple times under different conditions or over time.
# - Example: Measuring blood pressure of patients before, during, and after treatment.
#
# ### 4. Two-Way Repeated Measures ANOVA:
# - Combines the features of two-way ANOVA and repeated measures.
# - Involves **two within-subjects factors** or **one within-subjects and one between-subjects factor**.
#
# ## Q22. What is the F-test, and how does it relate to hypothesis testing?
#
# ### Answer:
# The **F-test** is a statistical test used to compare the variances of two or more groups to determine if they are significantly different. It is often used as part of **hypothesis testing**, especially in tests like ANOVA.
#
# ### How it Relates to Hypothesis Testing:
# - The F-test helps determine whether observed differences in group variances or means are statistically significant.
# - It is based on the **F-distribution**, which is always positive and right-skewed.
# - The F-statistic is calculated as the ratio of two variances:
#
# \[
# F = \frac{\text{Variance between groups}}{\text{Variance within groups}}
# \]

# %% [markdown]
# # Practical Part - 1

# %% [markdown]
# ## Q1. Write a Python program to generate a random variable and display its value.

# %%
import random

# Generate a random variable between 0 and 1
random_value = random.random()

# Display the value
print("Generated Random Value:", random_value)
# Out:
# Generated Random Value: 0.6629980933351051

# %% [markdown]
# ## Q2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters for discrete uniform distribution (e.g., integers from 1 to 6)
low = 1
high = 7  # upper bound is exclusive

# Generate a discrete uniform distribution
x = np.arange(low, high)
pmf = [1 / (high - low) for _ in x]  # Equal probability for all outcomes

# Plot the PMF
plt.stem(x, pmf, basefmt=" ")
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
from scipy.stats import bernoulli

# Function to calculate PDF of Bernoulli distribution
def bernoulli_pdf(p):
    x = [0, 1]  # Possible outcomes for Bernoulli distribution
    pdf_values = bernoulli.pmf(x, p)

    for xi, pdf in zip(x, pdf_values):
        print(f'P(X = {xi}) = {pdf:.2f}')

# Example: Bernoulli distribution with probability of success p = 0.6
bernoulli_pdf(0.6)
# Out:
# P(X = 0) = 0.40
# P(X = 1) = 0.60

# %% [markdown]
# ## Q4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for Binomial Distribution
n = 10  # number of trials
p = 0.5  # probability of success
size = 1000  # number of experiments

# Simulate the binomial distribution
binomial_data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(binomial_data, bins=np.arange(0, n+2)-0.5, edgecolor='black', density=True)
plt.title('Histogram of Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Relative Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters for Poisson Distribution
mu = 3  # average rate (lambda)
size = 1000  # number of samples

# Generate Poisson distributed data
poisson_data = np.random.poisson(mu, size)

# Visualize the distribution
plt.hist(poisson_data, bins=np.arange(0, max(poisson_data)+2)-0.5, edgecolor='black', density=True)
plt.title('Histogram of Poisson Distribution (λ = 3)')
plt.xlabel('Number of Events')
plt.ylabel('Relative Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Parameters for discrete uniform distribution (e.g., integers from 1 to 6)
low = 1
high = 7  # upper bound is exclusive

# Generate possible outcomes
x = np.arange(low, high)

# Calculate CDF using scipy's randint
cdf_values = randint.cdf(x, low, high)

# Plot the CDF
plt.step(x, cdf_values, where='post', color='blue', label='CDF')
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Outcome')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Q7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate continuous uniform distribution between 0 and 1
size = 1000  # number of samples
data = np.random.uniform(0, 1, size)

# Visualize the distribution with a histogram
plt.hist(data, bins=20, edgecolor='black', density=True, color='lightblue')
plt.title('Histogram of Continuous Uniform Distribution (0 to 1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for normal distribution
mean = 0     # Mean of the distribution
std_dev = 1  # Standard deviation
size = 1000  # Number of samples

# Generate normally distributed data
data = np.random.normal(mean, std_dev, size)

# Plot histogram
plt.hist(data, bins=30, edgecolor='black', density=True, color='lightgreen')
plt.title('Histogram of Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Function to calculate and plot Z-scores
def calculate_and_plot_zscores(data):
    z_scores = zscore(data)
    print("Z-scores:\n", z_scores)

    # Plot Z-scores
    plt.plot(z_scores, marker='o', linestyle='', color='red')
    plt.axhline(0, color='black', linewidth=1, linestyle='--')
    plt.title('Z-scores Plot')
    plt.xlabel('Data Point Index')
    plt.ylabel('Z-score')
    plt.grid(True)
    plt.show()

# Example dataset
data = np.random.normal(50, 10, 20)  # 20 random values from normal distribution

# Call the function
calculate_and_plot_zscores(data)
# Out:
# Z-scores:
#  [-0.20953688  1.34335111 -0.7068608  -0.75057069  2.2120179  -2.03030794
#  -0.00875694 -0.0883077  -0.92430307 -0.99136148  0.2372438  -0.89773873
#   0.96074139  1.27465514  0.00674189  0.28330362 -0.5577341  -0.83329297
#   1.24046282  0.44025364]

# %% [markdown]
# ## Q10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data from a non-normal distribution (Exponential)
population = np.random.exponential(scale=2, size=100000)

# Function to demonstrate CLT by taking sample means
sample_means = []
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples

for _ in range(num_samples):
    sample = np.random.choice(population, sample_size)
    sample_means.append(np.mean(sample))

# Plot histogram of the sample means
plt.hist(sample_means, bins=30, edgecolor='black', density=True, color='orange')
plt.title('Demonstration of CLT using Sample Means (Non-Normal Population)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mean = 50
std_dev = 10
population_size = 100000

# Generate population data from a normal distribution
population = np.random.normal(mean, std_dev, population_size)

# Function to demonstrate CLT by taking sample means
sample_means = []
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples

for _ in range(num_samples):
    sample = np.random.choice(population, sample_size)
    sample_means.append(np.mean(sample))

# Plot histogram of the sample means
plt.hist(sample_means, bins=30, edgecolor='black', density=True, color='lightblue')
plt.title('Verification of CLT using Sample Means (Normal Population)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Function to plot the Standard Normal Distribution
def plot_standard_normal_distribution():
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, 0, 1)  # mean = 0, std = 1

    plt.plot(x, y, color='blue', label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (Mean = 0, Std Dev = 1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# ## Q13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom

# Parameters for Binomial Distribution
n = 10  # number of trials
p = 0.5  # probability of success
size = 5  # number of random variables to generate

# Generate random variables
random_vars = np.random.binomial(n, p, size)
print("Generated Random Variables:", random_vars)

# Calculate and display the probability (PMF) for each generated variable
for rv in random_vars:
    probability = binom.pmf(rv, n, p)
    print(f'P(X = {rv}) = {probability:.4f}')
# Out:
# Generated Random Variables: [6 6 1 7 7]
# P(X = 6) = 0.2051
# P(X = 6) = 0.2051
# P(X = 1) = 0.0098
# P(X = 7) = 0.1172
# P(X = 7) = 0.1172

# %% [markdown]
# ## Q14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Example dataset
data = np.random.normal(50, 10, 100)  # 100 values with mean=50, std=10

# Given data point
x_value = 60

# Calculate Z-score
mean = np.mean(data)
std_dev = np.std(data)
z_score = (x_value - mean) / std_dev

print(f"Mean of dataset: {mean:.2f}")
print(f"Standard Deviation of dataset: {std_dev:.2f}")
print(f"Z-score for data point {x_value}: {z_score:.2f}")

# Plot the standard normal distribution
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.plot(x, y, label='Standard Normal Distribution', color='blue')
plt.axvline(z_score, color='red', linestyle='--', label=f'Z-score = {z_score:.2f}')
plt.title('Z-score Comparison with Standard Normal Distribution')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Mean of dataset: 49.57
# Standard Deviation of dataset: 10.63
# Z-score for data point 60: 0.98

# %% [markdown]
# ## Q15. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

# Sample dataset (e.g., test scores)
data = np.array([78, 85, 80, 76, 79, 82, 84, 88, 75, 81])

# Population mean (hypothesized value)
mu_0 = 80

# Known population standard deviation (for Z-test)
sigma = 5

# Sample mean and size
sample_mean = np.mean(data)
n = len(data)

# Calculate Z-statistic
z_stat = (sample_mean - mu_0) / (sigma / np.sqrt(n))
print(f"Z-statistic: {z_stat:.2f}")

# Calculate p-value for two-tailed test
p_value = 2 * (1 - norm.cdf(abs(z_stat)))
print(f"P-value: {p_value:.4f}")

# Significance level
alpha = 0.05

# Decision
if p_value < alpha:
    print("Reject the Null Hypothesis")
else:
    print("Fail to Reject the Null Hypothesis")
# Out:
# Z-statistic: 0.51
# P-value: 0.6129
# Fail to Reject the Null Hypothesis

# %% [markdown]
# ## Q16. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy.stats import norm

# Sample dataset (e.g., heights of individuals)
data = np.array([160, 165, 162, 170, 168, 164, 169, 167, 166, 171])

# Calculate sample mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data, ddof=1)  # ddof=1 for sample standard deviation
n = len(data)

# Confidence level (e.g., 95%)
confidence = 0.95
z_critical = norm.ppf(1 - (1 - confidence) / 2)

# Margin of error
margin_of_error = z_critical * (std_dev / np.sqrt(n))

# Confidence interval
lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 166.20
# 95% Confidence Interval: (164.02, 168.38)

# %% [markdown]
# ## Q17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy.stats import norm

# Generate data from a normal distribution
mean_population = 100
std_dev_population = 15
sample_size = 50

data = np.random.normal(mean_population, std_dev_population, sample_size)

# Calculate sample mean and standard deviation
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)

# Confidence level (95%)
confidence = 0.95
z_critical = norm.ppf(1 - (1 - confidence) / 2)

# Margin of error
margin_of_error = z_critical * (sample_std / np.sqrt(sample_size))

# Confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval for the Mean: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 102.06
# 95% Confidence Interval for the Mean: (97.53, 106.59)

# %% [markdown]
# ## Q18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 0
std_dev = 1

# Generate x values
x = np.linspace(-4, 4, 1000)

# Calculate the PDF
pdf = norm.pdf(x, mean, std_dev)

# Plot the PDF
plt.plot(x, pdf, color='green', label='Normal Distribution PDF')
plt.title('Probability Density Function of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Density')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Q19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

# Parameters for the Poisson distribution
lambda_val = 3  # average rate (mean)

# Range of possible values
x = np.arange(0, 15)

# Calculate the CDF
cdf = poisson.cdf(x, lambda_val)

# Display CDF values
for val, prob in zip(x, cdf):
    print(f'P(X ≤ {val}) = {prob:.4f}')

# Plot the CDF
plt.step(x, cdf, where='post', color='purple')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution (λ=3)')
plt.xlabel('Number of Events (x)')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.show()
# Out:
# P(X ≤ 0) = 0.0498
# P(X ≤ 1) = 0.1991
# P(X ≤ 2) = 0.4232
# P(X ≤ 3) = 0.6472
# P(X ≤ 4) = 0.8153
# P(X ≤ 5) = 0.9161
# P(X ≤ 6) = 0.9665
# P(X ≤ 7) = 0.9881
# P(X ≤ 8) = 0.9962
# P(X ≤ 9) = 0.9989
# P(X ≤ 10) = 0.9997
# P(X ≤ 11) = 0.9999
# P(X ≤ 12) = 1.0000
# P(X ≤ 13) = 1.0000
# P(X ≤ 14) = 1.0000

# %% [markdown]
# ## Q20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# Define the range for the continuous uniform distribution
a = 5
b = 15

# Simulate a random variable
random_var = np.random.uniform(a, b)
print(f"Simulated Random Variable: {random_var:.2f}")

# Calculate the expected value (mean) of the continuous uniform distribution
expected_value = (a + b) / 2
print(f"Expected Value (Mean) of the Distribution: {expected_value:.2f}")
# Out:
# Simulated Random Variable: 7.72
# Expected Value (Mean) of the Distribution: 10.00

# %% [markdown]
# ## Q21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
np.random.seed(0)  # for reproducibility
data1 = np.random.normal(50, 5, 100)   # mean=50, std=5
data2 = np.random.normal(50, 15, 100)  # mean=50, std=15

# Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Visualize the datasets using histograms
plt.hist(data1, bins=15, alpha=0.6, label='Dataset 1 (std=5)', color='blue', edgecolor='black')
plt.hist(data2, bins=15, alpha=0.6, label='Dataset 2 (std=15)', color='orange', edgecolor='black')
plt.title('Comparison of Two Datasets with Different Standard Deviations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 5.06
# Standard Deviation of Dataset 2: 15.60

# %% [markdown]
# ## Q22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np

# Generate dataset from a normal distribution
data = np.random.normal(100, 15, 100)  # mean = 100, std = 15, size = 100

# Calculate the Range
data_range = np.max(data) - np.min(data)

# Calculate the Interquartile Range (IQR)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Display results
print(f"Range of the Dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range of the Dataset: 76.15
# Interquartile Range (IQR): 17.03

# %% [markdown]
# ## Q23. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Generate a dataset
data = np.random.normal(50, 10, 100)  # mean=50, std=10, size=100

# Apply Z-score normalization
normalized_data = zscore(data)

# Plot original and normalized data
plt.figure(figsize=(12, 5))

# Original Data
plt.subplot(1, 2, 1)
plt.hist(data, bins=15, color='blue', alpha=0.7, edgecolor='black')
plt.title('Original Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)

# Normalized Data
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=15, color='green', alpha=0.7, edgecolor='black')
plt.title('Z-score Normalized Data')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()

# Display summary statistics
print(f"Original Data Mean: {np.mean(data):.2f}, Std Dev: {np.std(data, ddof=1):.2f}")
print(f"Normalized Data Mean: {np.mean(normalized_data):.2f}, Std Dev: {np.std(normalized_data, ddof=1):.2f}")
# Out:
# Original Data Mean: 48.03, Std Dev: 9.34
# Normalized Data Mean: 0.00, Std Dev: 1.01

# %% [markdown]
# ## Q24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

# Generate dataset from a normal distribution
data = np.random.normal(100, 15, 1000)

# Function to calculate skewness and kurtosis
def calculate_skewness_kurtosis(dataset):
    skewness = skew(dataset)
    kurt = kurtosis(dataset)  # By default, Fisher's definition: normal dist = 0
    return skewness, kurt

# Call the function
skewness, kurt = calculate_skewness_kurtosis(data)

# Display the results
print(f"Skewness of the Dataset: {skewness:.4f}")
print(f"Kurtosis of the Dataset: {kurt:.4f}")
# Out:
# Skewness of the Dataset: 0.0230
# Kurtosis of the Dataset: 0.0589

# %% [markdown]
# #Practical Part - 2

# %% [markdown]
# ## Q1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %%
import numpy as np
from scipy.stats import norm

# Known population parameters
population_mean = 100
population_std = 15

# Sample data
sample = np.array([102, 98, 105, 100, 110, 95, 99, 101, 104, 103])
sample_mean = np.mean(sample)
sample_size = len(sample)

# Perform Z-test
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate p-value (two-tailed)
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Display results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the sample mean and the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the sample mean and the population mean.")
# Out:
# Sample Mean: 101.70
# Z-score: 0.3584
# P-value: 0.7201
# Fail to reject the null hypothesis: No significant difference between the sample mean and the population mean.

# %% [markdown]
# ## Q2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy.stats import ttest_1samp

# Simulate random data (sample)
np.random.seed(0)
data = np.random.normal(50, 10, 30)  # mean = 50, std = 10, sample size = 30

# Perform one-sample t-test
# Null hypothesis: The population mean is 50
t_stat, p_value = ttest_1samp(data, popmean=50)

# Display results
print(f"Sample Mean: {np.mean(data):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean significantly differs from 50.")
else:
    print("Fail to reject the null hypothesis: No significant difference from 50.")
# Out:
# Sample Mean: 54.43
# T-statistic: 2.2045
# P-value: 0.0356
# Reject the null hypothesis: The sample mean significantly differs from 50.

# %% [markdown]
# ## Q3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = np.array([52, 49, 55, 51, 50, 48, 53, 50, 49, 54])
sample_mean = np.mean(sample)
sample_size = len(sample)

# Known population parameters
population_mean = 50
population_std = 4  # Assumed known

# Calculate Z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate p-value (two-tailed test)
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Display results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean significantly differs from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the sample mean and the population mean.")
# Out:
# Sample Mean: 51.10
# Z-score: 0.8696
# P-value: 0.3845
# Fail to reject the null hypothesis: No significant difference between the sample mean and the population mean.

# %% [markdown]
# ## Q4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
sample = np.array([102, 98, 105, 100, 110, 95, 99, 101, 104, 103])
sample_mean = np.mean(sample)
sample_size = len(sample)

# Known population parameters
population_mean = 100
population_std = 5  # assumed known

# Calculate Z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Two-tailed test at 5% significance level
alpha = 0.05
z_critical = norm.ppf(1 - alpha/2)

# Display results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.4f}")
print(f"Z-critical value (±{z_critical:.2f}) for 95% confidence")

# Plot standard normal distribution with decision regions
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y, label='Standard Normal Distribution')
plt.fill_between(x, y, where=(x <= -z_critical), color='red', alpha=0.3, label='Rejection Region')
plt.fill_between(x, y, where=(x >= z_critical), color='red', alpha=0.3)
plt.axvline(z_score, color='blue', linestyle='--', label=f'Z-score = {z_score:.2f}')
plt.title('Two-Tailed Z-Test with Decision Regions')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# Interpretation
if abs(z_score) > z_critical:
    print("Reject the null hypothesis: Sample mean significantly differs from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the population mean.")
# Out:
# Sample Mean: 101.70
# Z-score: 1.0752
# Z-critical value (±1.96) for 95% confidence
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# ## Q5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Function to visualize Type 1 and Type 2 errors
def visualize_errors(mu_null=0, mu_alt=1, sigma=1, alpha=0.05):
    # Critical value for two-tailed test
    z_critical = norm.ppf(1 - alpha/2)

    # Define x range
    x = np.linspace(mu_null - 4*sigma, mu_alt + 4*sigma, 1000)

    # Null and Alternative distributions
    y_null = norm.pdf((x - mu_null) / sigma)
    y_alt = norm.pdf((x - mu_alt) / sigma)

    plt.plot(x, y_null, label='Null Hypothesis Distribution', color='blue')
    plt.plot(x, y_alt, label='Alternative Hypothesis Distribution', color='green')

    # Rejection regions
    critical_left = mu_null - z_critical * sigma
    critical_right = mu_null + z_critical * sigma

    # Shade Type 1 Error regions (α)
    plt.fill_between(x, y_null, where=(x < critical_left), color='red', alpha=0.3, label='Type 1 Error (α)')
    plt.fill_between(x, y_null, where=(x > critical_right), color='red', alpha=0.3)

    # Shade Type 2 Error region (β)
    plt.fill_between(x, y_alt, where=(x > critical_left) & (x < critical_right), color='orange', alpha=0.3, label='Type 2 Error (β)')

    plt.axvline(critical_left, color='black', linestyle='--', label='Critical Values')
    plt.axvline(critical_right, color='black', linestyle='--')

    plt.title('Type 1 and Type 2 Errors in Hypothesis Testing')
    plt.xlabel('Test Statistic')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function
visualize_errors()

# %% [markdown]
# ## Q6. Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Generate two independent samples
np.random.seed(1)
group1 = np.random.normal(55, 10, 30)  # Mean = 55, Std = 10, Size = 30
group2 = np.random.normal(50, 10, 30)  # Mean = 50, Std = 10, Size = 30

# Perform Independent T-test
t_stat, p_value = ttest_ind(group1, group2)

# Display results
print(f"Group 1 Mean: {np.mean(group1):.2f}")
print(f"Group 2 Mean: {np.mean(group2):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The means of the two groups are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the means of the two groups.")
# Out:
# Group 1 Mean: 54.40
# Group 2 Mean: 50.77
# T-statistic: 1.4981
# P-value: 0.1395
# Fail to reject the null hypothesis: No significant difference between the means of the two groups.

# %% [markdown]
# ## Q7. Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Generate paired sample data (before and after)
np.random.seed(2)
before = np.random.normal(60, 8, 30)
after = before + np.random.normal(2, 3, 30)  # Assume a slight improvement after treatment

# Perform Paired Sample T-test
t_stat, p_value = ttest_rel(before, after)

# Display results
print(f"Mean Before: {np.mean(before):.2f}")
print(f"Mean After: {np.mean(after):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference before and after.")
else:
    print("Fail to reject the null hypothesis: No significant difference before and after.")

# Visualization
plt.figure(figsize=(8,5))
plt.plot(before, 'o-', label='Before')
plt.plot(after, 's-', label='After')
plt.title('Paired Sample Comparison')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Before: 57.35
# Mean After: 59.66
# T-statistic: -4.0243
# P-value: 0.0004
# Reject the null hypothesis: There is a significant difference before and after.

# %% [markdown]
# ## Q8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy.stats import ttest_1samp, norm

# Simulate sample data
np.random.seed(3)
sample = np.random.normal(100, 15, 25)  # Mean = 100, Std = 15, Sample size = 25

# Known population parameters
population_mean = 100
population_std = 15  # Assumed known for Z-test

# ---------------- Z-test ----------------
sample_mean = np.mean(sample)
sample_size = len(sample)
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value_z = 2 * (1 - norm.cdf(abs(z_score)))

# ---------------- T-test ----------------
t_stat, p_value_t = ttest_1samp(sample, population_mean)

# ---------------- Results ----------------
print(f"Sample Mean: {sample_mean:.2f}")
print(f"\n--- Z-test Results ---")
print(f"Z-score: {z_score:.4f}")
print(f"P-value (Z-test): {p_value_z:.4f}")

print(f"\n--- T-test Results ---")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value (T-test): {p_value_t:.4f}")

# ---------------- Interpretation ----------------
alpha = 0.05
print("\nInterpretation:")
if p_value_z < alpha:
    print("Z-test: Reject the null hypothesis.")
else:
    print("Z-test: Fail to reject the null hypothesis.")

if p_value_t < alpha:
    print("T-test: Reject the null hypothesis.")
else:
    print("T-test: Fail to reject the null hypothesis.")
# Out:
# Sample Mean: 98.50
#
# --- Z-test Results ---
# Z-score: -0.5000
# P-value (Z-test): 0.6171
#
# --- T-test Results ---
# T-statistic: -0.5058
# P-value (T-test): 0.6176
#
# Interpretation:
# Z-test: Fail to reject the null hypothesis.
# T-test: Fail to reject the null hypothesis.

# %% [markdown]
# ## Q9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy.stats import t

# Function to calculate confidence interval for sample mean
def confidence_interval(sample, confidence=0.95):
    n = len(sample)
    mean = np.mean(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)

    # t-critical value
    t_critical = t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_critical * std_err
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return lower_bound, upper_bound

# Simulate sample data
np.random.seed(4)
sample = np.random.normal(100, 15, 30)

# Calculate confidence interval
lower, upper = confidence_interval(sample)
print(f"95% Confidence Interval for the Sample Mean: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% Confidence Interval for the Sample Mean: (95.01, 106.06)

# %% [markdown]
# ## Q10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy.stats import t

# Function to calculate margin of error
def margin_of_error(sample, confidence=0.95):
    n = len(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)
    t_critical = t.ppf((1 + confidence) / 2, df=n-1)
    moe = t_critical * std_err
    return moe

# Simulate sample data
np.random.seed(5)
sample = np.random.normal(80, 10, 40)

# Calculate margin of error
moe = margin_of_error(sample)
print(f"Margin of Error at 95% confidence level: {moe:.2f}")
# Out:
# Margin of Error at 95% confidence level: 2.91

# %% [markdown]
# ## Q11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
# Example of Bayesian Inference using Bayes' Theorem

# Define probabilities
P_Disease = 0.01         # Prior probability: 1% chance a person has the disease
P_Positive_given_Disease = 0.99  # Test is 99% accurate if disease present (True Positive)
P_Positive_given_NoDisease = 0.05  # 5% False Positive rate
P_NoDisease = 1 - P_Disease

# Apply Bayes' Theorem
# P(Disease | Positive) = [P(Positive | Disease) * P(Disease)] / P(Positive)

# Total probability of testing positive
P_Positive = (P_Positive_given_Disease * P_Disease) + (P_Positive_given_NoDisease * P_NoDisease)

# Posterior probability: probability of having the disease given a positive test
P_Disease_given_Positive = (P_Positive_given_Disease * P_Disease) / P_Positive

# Display results
print(f"Probability of having the disease given a positive test: {P_Disease_given_Positive * 100:.2f}%")
# Out:
# Probability of having the disease given a positive test: 16.67%

# %% [markdown]
# ## Q12. Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table
# Example: Relationship between Gender and Preference
data = np.array([[30, 20],   # Male: 30 prefer A, 20 prefer B
                 [25, 25]])  # Female: 25 prefer A, 25 prefer B

# Convert to DataFrame for better readability
table = pd.DataFrame(data, columns=['Preference A', 'Preference B'], index=['Male', 'Female'])

print("Contingency Table:")
print(table)

# Perform Chi-square test for independence
chi2_stat, p_value, dof, expected = chi2_contingency(table)

# Display results
print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant association between the variables.")
else:
    print("Fail to reject the null hypothesis: No significant association between the variables.")
# Out:
# Contingency Table:
#         Preference A  Preference B
# Male              30            20
# Female            25            25
#
# Chi-square Statistic: 0.6465
# Degrees of Freedom: 1
# P-value: 0.4214
# Fail to reject the null hypothesis: No significant association between the variables.

# %% [markdown]
# ## Q13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Observed data (contingency table)
data = np.array([[40, 35],
                 [30, 45]])

# Convert to DataFrame for better readability
table = pd.DataFrame(data, columns=['Category A', 'Category B'], index=['Group 1', 'Group 2'])

print("Observed Frequencies (Contingency Table):")
print(table)

# Calculate expected frequencies using chi2_contingency
chi2_stat, p_value, dof, expected = chi2_contingency(table)

# Display expected frequencies
expected_df = pd.DataFrame(expected, columns=table.columns, index=table.index)
print("\nExpected Frequencies:")
print(expected_df.round(2))
# Out:
# Observed Frequencies (Contingency Table):
#          Category A  Category B
# Group 1          40          35
# Group 2          30          45
#
# Expected Frequencies:
#          Category A  Category B
# Group 1        35.0        40.0
# Group 2        35.0        40.0

# %% [markdown]
# ## Q14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
from scipy.stats import chisquare

# Observed data
observed = np.array([50, 30, 20])

# Expected distribution - sum must match observed
total = np.sum(observed)
expected = np.array([total/3, total/3, total/3])  # Assuming equal distribution

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Display results
print(f"Observed Counts: {observed}")
print(f"Expected Counts: {expected.round(2)}")

print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")
# Out:
# Observed Counts: [50 30 20]
# Expected Counts: [33.33 33.33 33.33]
#
# Chi-square Statistic: 14.0000
# P-value: 0.0009
# Reject the null hypothesis: The observed data does not fit the expected distribution.
